# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
flower = sns.load_dataset('iris')
flower.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
flower.sample(20)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 67            5.8          2.7           4.1          1.0  versicolor
# 138           6.0          3.0           4.8          1.8   virginica
# 147           6.5          3.0           5.2          2.0   virginica
# 6             4.6          3.4           1.4          0.3      setosa
# 42            4.4          3.2           1.3          0.2      setosa
# 48            5.3          3.7           1.5          0.2      setosa
# 41            4.5          2.3           1.3          0.3      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 91            6.1          3.0           4.6          1.4  versicolor
# 68            6.2          2.2           4.5          1.5  versicolor
# 116           6.5          3.0           5.5          1.8   virginica
# 58            6.6          2.9           4.6          1.3  versicolor
# ...

# %%
flower.to_excel('flower.xlsx')

# %%
df = pd.read_excel('flower.xlsx')
df.head()
# Out:
#    Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width species
# 0           0           5.1          3.5           1.4          0.2  setosa
# 1           1           4.9          3.0           1.4          0.2  setosa
# 2           2           4.7          3.2           1.3          0.2  setosa
# 3           3           4.6          3.1           1.5          0.2  setosa
# 4           4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# #### Selecting the columns
# ###### Note: If you want to select only one column then use single square bracket ( One Dimensional Array )
# ###### Note: If you want to select more than two column then use double square bracket ( Two dimensional array)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'sepal_length', 'sepal_width', 'petal_length',
#        'petal_width', 'species'],
#       dtype='object')

# %%
df['species']
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
df[['species','petal_length']].sample(5)
# Out:
#        species  petal_length
# 44      setosa           1.9
# 21      setosa           1.5
# 0       setosa           1.4
# 15      setosa           1.5
# 85  versicolor           4.5

# %%
df.head(5)
# Out:
#    Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width species
# 0           0           5.1          3.5           1.4          0.2  setosa
# 1           1           4.9          3.0           1.4          0.2  setosa
# 2           2           4.7          3.2           1.3          0.2  setosa
# 3           3           4.6          3.1           1.5          0.2  setosa
# 4           4           5.0          3.6           1.4          0.2  setosa

# %%
df = df.drop(columns='Unnamed: 0')

# %%
df.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 131           7.9          3.8           6.4          2.0   virginica
# 34            4.9          3.1           1.5          0.2      setosa
# 48            5.3          3.7           1.5          0.2      setosa
# 83            6.0          2.7           5.1          1.6  versicolor
# 142           5.8          2.7           5.1          1.9   virginica

# %% [markdown]
# ##### Data about each species

# %%
df.groupby('species').describe().T
# Out:
# species                setosa  versicolor  virginica
# sepal_length count  50.000000   50.000000  50.000000
#              mean    5.006000    5.936000   6.588000
#              std     0.352490    0.516171   0.635880
#              min     4.300000    4.900000   4.900000
#              25%     4.800000    5.600000   6.225000
#              50%     5.000000    5.900000   6.500000
#              75%     5.200000    6.300000   6.900000
#              max     5.800000    7.000000   7.900000
# sepal_width  count  50.000000   50.000000  50.000000
#              mean    3.428000    2.770000   2.974000
#              std     0.379064    0.313798   0.322497
#              min     2.300000    2.000000   2.200000
#              25%     3.200000    2.525000   2.800000
#              50%     3.400000    2.800000   3.000000
#              75%     3.675000    3.000000   3.175000
#              max     4.400000    3.400000   3.800000
# petal_length count  50.000000   50.000000  50.000000
# ...

# %%
df.groupby("species").count()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa                50           50            50           50
# versicolor            50           50            50           50
# virginica             50           50            50           50

# %% [markdown]
# ##### Data count about each species

# %%
df.groupby(["species","sepal_width"]).count()
# Out:
#                         sepal_length  petal_length  petal_width
# species    sepal_width
# setosa     2.3                     1             1            1
#            2.9                     1             1            1
#            3.0                     6             6            6
#            3.1                     4             4            4
#            3.2                     5             5            5
#            3.3                     2             2            2
#            3.4                     9             9            9
#            3.5                     6             6            6
#            3.6                     3             3            3
#            3.7                     3             3            3
#            3.8                     4             4            4
#            3.9                     2             2            2
#            4.0                     1             1            1
# ...

# %% [markdown]
# ##### Reading the titanic dataset to work on it!

# %%
df2 = pd.read_excel(r"D:\python data science\pandas_practise01\titanic.xlsx")
df2.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %% [markdown]
# ##### Dropiing the index column

# %%
df2.drop(['Unnamed: 0'], axis=1)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ##### Counting the data according to the specific column

# %%
# survived, embarked town, sex, who, ki base pr data ki counting 
df2.groupby(["survived","embark_town","sex","who"]).count()
# Out:
#                                    Unnamed: 0  pclass  age  sibsp  parch  \
# survived embark_town sex    who
# 0        Cherbourg   female child           2       2    2      2      2
#                             woman           7       7    4      7      7
#                      male   child           2       2    2      2      2
#                             man            64      64   43     64     64
#          Queenstown  female woman           9       9    5      9      9
#                      male   child           4       4    4      4      4
#                             man            34      34   11     34     34
#          Southampton female child          13      13   13     13     13
#                             woman          50      50   40     50     50
#                      male   child          13      13   13     13     13
#                             man           351     351  287    351    351
# ...

# %% [markdown]
# ##### Plotting the graph using the seaborn library

# %%
# X-axis pr survived or Y-axis pr count
sns.countplot(x="survived", hue='who', data=df2)
# Out:
# <AxesSubplot: xlabel='survived', ylabel='count'>

# %% [markdown]
# #### python group by

# %%
df2.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %%
df2.drop(['Unnamed: 0'], axis=1).head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df2.groupby(["sex","deck","who"]).count()
# Out:
#                    Unnamed: 0  survived  pclass  age  sibsp  parch  fare  \
# sex    deck who
# female A    woman           1         1       1    1      1      1     1
#        B    child           2         2       2    2      2      2     2
#             woman          25        25      25   24     25     25    25
#        C    child           1         1       1    1      1      1     1
#             woman          26        26      26   24     26     26    26
#        D    woman          18        18      18   17     18     18    18
#        E    woman          15        15      15   13     15     15    15
#        F    child           1         1       1    1      1      1     1
#             woman           4         4       4    3      4      4     4
#        G    child           2         2       2    2      2      2     2
#             woman           2         2       2    2      2      2     2
# male   A    child           1         1       1    1      1      1     1
# ...

# %%
sns.countplot(x="sex",hue="deck",data=df2)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='count'>

# %%
df2.describe()
# Out:
#        Unnamed: 0    survived      pclass         age       sibsp       parch  \
# count  891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean   445.000000    0.383838    2.308642   29.699118    0.523008    0.381594
# std    257.353842    0.486592    0.836071   14.526497    1.102743    0.806057
# min      0.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%    222.500000    0.000000    2.000000   20.125000    0.000000    0.000000
# 50%    445.000000    0.000000    3.000000   28.000000    0.000000    0.000000
# 75%    667.500000    1.000000    3.000000   38.000000    1.000000    0.000000
# max    890.000000    1.000000    3.000000   80.000000    8.000000    6.000000
#
#              fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200
